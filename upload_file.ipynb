# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
x = np.arange(1, 10)
y = np.sin(x)

# %%
import io
figure = io.BytesIO()
plt.plot(x, y)
plt.savefig(figure, format="png")

# %%
import requests

r = requests.post('http://0.0.0.0:8000/api/properties/a5a7157a-0d12-444e-99b2-d93490f10b3e/upload', 
                  headers={'Authorization': 'Token ***REMOVED***'},
                  data={"part": "ca16171c-048b-4d53-8d07-6af22bcea702"},
                  files={"attachment": ('plot.png', figure.getvalue(), 'image/png')})

print(r.text)
# Out:
# {'success': true}
